# %%
using Dleto

randSurfaceTensor([0.0], [0.0], [0.0], 1.0)
# Out:
# UndefVarError: `randSurfaceTensor` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W0sdW50aXRsZWQ=.jl:3
